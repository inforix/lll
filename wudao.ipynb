# %%
import os
import torch
from flagai.auto_model.auto_loader import AutoLoader
from flagai.model.predictor.predictor import Predictor
from flagai.data.tokenizer import Tokenizer
import bminf
# Out:
# [2023-06-11 09:53:41,509] [INFO] [logger.py:85:log_dist] [Rank -1] Unsupported bmtrain

# %%
torch.cuda.is_available = lambda: False

state_dict = "../models/"
model_name = 'aquila-7b' # 'aquila-33b'
os.environ['DS_ACCELERATOR'] = "cpu"

loader = AutoLoader(
    "lm",
    model_dir=state_dict,
    model_name=model_name,
    device = "cpu",
    use_cache=True)
model = loader.get_model()
tokenizer = loader.get_tokenizer()

model.eval()
model.half()
#model.cuda()
# Out:
# ******************** lm aquila-7b
# model checkpoint_path=../models/aquila-7b/pytorch_model.bin are loaded successfully...
# All special tokens:  [('pad', '<|endoftext|>', 0), ('eos', '<|endoftext|>', 0), ('sop', '<|startofpiece|>', 100000), ('eop', '<|endofpiece|>', 100001), ('cls', '[CLS]', 100006), ('MASK', '[MASK]', 100003), ('sep', '</s>', 100007), ('unk', '[UNK]', 0), ('gMASK', '[gMASK]', 100004), ('sMASK', '[sMASK]', 100005)]
# AQUILAModel(
#   (tok_embeddings): Embedding(100008, 4096)
#   (layers): ModuleList(
#     (0): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (1): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (2): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (3): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (4): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (5): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (6): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (7): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (8): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (9): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (10): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (11): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (12): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (13): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (14): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (15): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (16): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (17): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (18): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (19): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (20): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (21): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (22): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (23): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (24): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (25): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (26): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (27): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (28): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (29): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (30): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#     (31): AQUILABlock(
#       (attention): AQUILAAttention(
#         (wq): Linear(in_features=4096, out_features=4096, bias=False)
#         (wk): Linear(in_features=4096, out_features=4096, bias=False)
#         (wv): Linear(in_features=4096, out_features=4096, bias=False)
#         (wo): Linear(in_features=4096, out_features=4096, bias=False)
#       )
#       (feed_forward): AQUILAForward(
#         (w1): Linear(in_features=4096, out_features=11008, bias=False)
#         (w2): Linear(in_features=11008, out_features=4096, bias=False)
#         (w3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#       (attention_norm): RMSNorm()
#       (ffn_norm): RMSNorm()
#     )
#   )
#   (norm): RMSNorm()
#   (output): Linear(in_features=4096, out_features=100008, bias=False)
#   (loss_func): CrossEntropyLoss()
# )

# %%
predictor = Predictor(model, tokenizer)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.dtype
#
# File ~/lll/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1269, in Module.__getattr__(self, name)
#    1267     if name in modules:
#    1268         return modules[name]
# -> 1269 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1270     type(self).__name__, name))
#
# AttributeError: 'AQUILAModel' object has no attribute 'dtype'

# %%
text = "北京在哪儿?"
text = f'{text}' 
print(f"text is {text}")
with torch.no_grad():
    out = predictor.predict_generate_randomsample(text, out_max_length=200, temperature=0)
    print(f"pred is {out}")
# Out:
# text is 北京在哪儿?
# /home/xxb/lll/.venv/lib/python3.10/site-packages/flagai-1.7.1-py3.10.egg/flagai/model/predictor/aquila.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tokens[k, : len(t)] = torch.tensor(t).long()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(f"text is {text}")
#       4 with torch.no_grad():
# ----> 5     out = predictor.predict_generate_randomsample(text, out_max_length=200, temperature=0)
#       6     print(f"pred is {out}")
#
# File ~/lll/.venv/lib/python3.10/site-packages/flagai-1.7.1-py3.10.egg/flagai/model/predictor/predictor.py:352, in Predictor.predict_generate_randomsample(self, text, input_max_length, out_max_length, top_k, top_p, repetition_penalty, temperature, prompts_tokens)
#     347     return bert_random_sample(self.model, self.tokenizer, text,
#     348                               input_max_length, out_max_length, top_k,
#     349                               top_p, repetition_penalty, temperature,
#     350                               device)
#     351 elif "aquila" in self.class_name.lower():
# --> 352     return aquila_generate(self.tokenizer, self.model,
#     353                           [text], out_max_length,
#     354                           temperature, top_p, prompts_tokens=prompts_tokens)
#     356 else:
#     357     print("Unsupported decoding mode")
#
# File ~/lll/.venv/lib/python3.10/site-packages/flagai-1.7.1-py3.10.egg/flagai/model/predictor/aquila.py:37, in aquila_generate(tokenizer, model, prompts, max_gen_len, temperature, top_p, prompts_tokens)
#      35 prev_pos = 0
#      36 for cur_pos in range(start_pos, total_len):
# ---> 37     logits = model.forward(tokens[:, prev_pos:cur_pos], prev_pos)["logits"]
#      38     #print(logits.shape)
#      39     if temperature > 0:
#
# File ~/lll/.venv/lib/python3.10/site-packages/flagai-1.7.1-py3.10.egg/flagai/model/aquila_model.py:200, in AQUILAModel.forward(self, input_ids, start_pos, labels, **kwargs)
#     198     h = checkpoint(create_custom_forward(self.tok_embeddings),input_ids)
#     199 else:
# --> 200     h = self.tok_embeddings(input_ids)
#     202 self.freqs_cis = self.freqs_cis.to(h.device)
#     203 freqs_cis = self.freqs_cis[start_pos : start_pos + seqlen]
#
# File ~/lll/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/lll/.venv/lib/python3.10/site-packages/torch/nn/modules/sparse.py:160, in Embedding.forward(self, input)
#     159 def forward(self, input: Tensor) -> Tensor:
# --> 160     return F.embedding(
#     161         input, self.weight, self.padding_idx, self.max_norm,
#     162         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/lll/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument index in method wrapper__index_select)
